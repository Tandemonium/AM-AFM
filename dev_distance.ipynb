# %%
# source ~/venv/amafm/Scripts/activate
# %load_ext autoreload
# %autoreload 2

DATA_DIR = '../experiments'

# %%
from amafm import evaluation
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %% [markdown]
# ### Label all curves by minimal distance from pre-selection

# %%
dist_classification = evaluation.ClassificationByDistance(DATA_DIR, ['0041_002', '0044_005'], test_size=0.25)
# Out:
# ...
# Step 4/4: x-alignment: 100%|██████████| 194/194 [00:00<00:00, 12923.38it/s]

# %%
dist_classification.by_min_norm(k=40)
# Out:
# Validation cycle: 100%|██████████| 40/40 [00:11<00:00,  3.47it/s]
# Mean accuracy (min norm): 71.72%

# %%
dist_classification.by_mean_norm(k=40)
# Out:
# Validation cycle: 100%|██████████| 40/40 [00:12<00:00,  3.33it/s]
# Mean accuracy (mean norm): 66.66%

# %%
dist_classification.by_correlation(k=40)
# Out:
# Validation cycle: 100%|██████████| 40/40 [01:15<00:00,  1.90s/it]
# Mean accuracy (correlation): 70.62%

# %%
dist_classification.by_dtw(k=40)
# Out:
# Validation cycle: 100%|██████████| 40/40 [11:37<00:00, 17.43s/it]
# Mean accuracy (dtw): 73.38%

# %%
dist_classification.by_procrustes(k=40)
# Out:
# Validation cycle: 100%|██████████| 40/40 [1:13:55<00:00, 110.88s/it]
# Mean accuracy (procrustes): 62.60%
